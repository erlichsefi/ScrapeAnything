# %%
with open("/workspaces/ScrapeAnything/outputs/20230810_140715_b96dfd92_2c8c_41a4_8ae5_36a7f1c7dbc4/step_1.html",'r') as f:
    content = f.read()

# %%
# https://github.com/aaronsw/html2text
# prcoess images with > https://github.com/ParhamP/altify
# process elements with > https://github.com/kagermanov27/daath-ai-parser

import html2text
print(html2text.html2text(content))
# Out:
# לחץ על Alt+1 עבור מצב קריאת מסך, Alt+0 לביטול[מדריך קורא מסך, משוב ודיווח על
# בעיות](https://accessibe.com/blog/knowledgebase/screen-reader-guide)
#
# __
#
# ![logo-img](../assets/images/icons/v2/instagram.svg)![logo-
# img](../assets/images/icons/v2/facebook.svg)
#
# [באר
# המשאלות
#
# ![logo-img](../assets/images/icons/v2/hebrew-logo-cut.png)](/)
#
# התחברות
#
# הענקנו כבר
#
# 399,208
#
# מטבעות משאלה
#
# ![girl-coins](https://wishingwell-bucket.s3.amazonaws.com/graphics/girl-
# coins.png)
#
# ####  **לאנשים שעושים טוב**
#
# ####  **מגיע יותר מתודה!**
#
# ####  הטבות ומתנות לכל מי שתורם מעצמו לעולם
#
# #  מצטרפים אלינו?
#
# # הטבות שכבר מחכות למימוש
#
# ![headline-line](assets/images/icons/v2/headline-line.svg)
#
# ![](../assets/images/icons/v2/single-view-left-arrow.svg)
#
# ![בורגוס רינגס במתנה בכל הצטרפות למועדון BBB CLUB!](https://wishingwell-
# bucket.s3.amazonaws.com/logos/retailers/bbb-new_logo.webp)
#
# ...

# %%
# https://github.com/weblyzard/inscriptis
from inscriptis import get_text
text = get_text(content)
print(text)
# Out:
# לחץ על Alt+1 עבור מצב קריאת מסך, Alt+0 לביטול מדריך קורא מסך, משוב ודיווח על בעיות
#
#             באר
#             המשאלות
#
#             התחברות
#                 הענקנו כבר
#                 399,208
#                 מטבעות משאלה
#
#           לאנשים שעושים טוב
#
#           מגיע יותר מתודה!
#
#           הטבות ומתנות לכל מי שתורם מעצמו לעולם
#
#               מצטרפים אלינו?
#
#       הטבות שכבר מחכות למימוש
#
#                                     3
#                                     משאלות
#
#                                       שובר בשווי 100 ₪ למימוש במגוון מותגי קבוצת קסטרו הודיס במחיר של 80 ₪!
#
#                                       שובר בשווי 100 ש"ח למימוש במגוון מוצרי קבוצת קסטרו הודיס: קסטרו, קסטרו HOME, הודיס, קרולינה למקה, אורבניקה, איב רושה, טופ-טן, קיקו מילאנו, אדידס ובייביסטאר, במחיר מיוחד למתנדבים: 80 ש"ח בלבד כולל מע"מ! יש לשלם דרך הקישור 'לתשלום אונליין'. לאחר התשלום לא ניתן לקבל החזר.
#
#                                     35
# ...
